# %% [markdown]
# # Markdown
# ## Math mode
# To **insert _inline_** a __mathematical__ _formula_ we use the *dollar* symbol, as follows:
# Euler's identity: $e^{i \pi} + 1 = 0$
# To isolate and center the formulas and enter in math display mode, we use double dollar symbol:
# Euler's identity: $$\boxed{e^{i \pi} + 1 = 0}$$
# NOTE: no spaces before or after *dollar* sign

# %% [markdown]
# ## Math Samples
# $\sum \limits_{k=0}^\infty \left[ \lim \limits_{a \to 0} \int \limits_{-a}^{a} \binom nk \frac{1+x^{n-k}}{1+x^k} \right] \text{could be } 0$
# $\underset{x > 0}{\overset{y<0}\Longrightarrow}$
# $\require{cancel} \frac{x(\cancel{x+1})}{(\cancel{x+1})(x+2)} \to \alpha$ so
# $\int \limits_{a}^{b} \left\lceil \frac {1}{1+x^2} \right\rceil dx$

# %% [markdown]
# ## Tables
#
# Use [Markdown Table Generator](https://www.tablesgenerator.com/markdown_tables)
#
# | Name                   |                                   Differential                                  |         By Components         |
# |------------------------|:-------------------------------------------------------------------------------:|:-----------------------------:|
# | Gauss                  | $\pmb \nabla \cdot \pmb E = 4 \pi \rho$                                         | $\partial_i E^i = 4 \pi J^0$  |
# | Gauss for magnetism    | $\pmb \nabla \cdot \pmb B = 0$                                                  | $\partial_i B^i = 0$          |
# | Maxwell–Faraday        | $\pmb \nabla \times \pmb E + \frac{\partial \pmb B}{\partial t} = 0$            | $\partial_i E^i = 4 \pi J^0$  |
# | Ampère's circuital law | $\pmb \nabla \times \pmb B - \frac{\partial \pmb E}{\partial t} = 4 \pi \pmb J$ | $\partial_i E^i = 4 \pi J^0$  |

# %%
from IPython.display import display, Math
import numpy as np
def print_matrix(array,format = '%.3f'):
    data = ''
    for line in array:        
        for element in line:
            data += format % element + ' & '
        data = data.rstrip(' &')
        data += r'\\' + '\n'
    # print(data)
    display(Math('\\begin{pmatrix} \n%s\end{pmatrix}'%data))

indI,indJ = np.indices((4,4))
print_matrix((indI+1)*10+indJ+1)
# Out:
# $\displaystyle \begin{pmatrix}
# 11.000 & 12.000 & 13.000 & 14.000\\
# 21.000 & 22.000 & 23.000 & 24.000\\
# 31.000 & 32.000 & 33.000 & 34.000\\
# 41.000 & 42.000 & 43.000 & 44.000\\
# \end{pmatrix}$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.tri as mtri
from matplotlib.ticker import LinearLocator

fig, ax = plt.subplots(subplot_kw={"projection": "3d"},figsize=(30,10))


# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
